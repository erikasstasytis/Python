# %%
# import libraries needed
import numpy as np
import pandas as pd

# %% [markdown]
# # Assignment 1: Series Basics
#
# The code has been previded to create an array, `oil_array` from a dataframe column.
#
# * Convert `oil_array` into a Pandas Series, called `oil_series`. Give it a name!
# * Return the name, dtype, size, and index of `oil_series`.
#
# Take the mean of the values array.
#
# Then, convert the series to integer datatype and recalculate the mean.

# %%
# create a DataFrame from the oil file, drop missing values
oil = pd.read_csv("files/oil.csv").dropna()

# Grab 100 rows of oil prices
oil_array = np.array(oil["dcoilwtico"].iloc[1000:1100])

oil_array
# Out:
# array([52.22, 51.44, 51.98, 52.01, 52.82, 54.01, 53.8 , 53.75, 52.36,
#        53.26, 53.77, 53.98, 51.95, 50.82, 52.19, 53.01, 52.36, 52.45,
#        51.12, 51.39, 52.33, 52.77, 52.38, 52.14, 53.24, 53.18, 52.63,
#        52.75, 53.9 , 53.55, 53.81, 53.01, 52.19, 52.37, 52.99, 53.84,
#        52.96, 53.21, 53.11, 53.41, 53.41, 54.02, 53.61, 54.48, 53.99,
#        54.04, 54.  , 53.82, 52.63, 53.33, 53.19, 52.68, 49.83, 48.75,
#        48.05, 47.95, 47.24, 48.34, 48.3 , 48.34, 47.79, 47.02, 47.29,
#        47.  , 47.3 , 47.02, 48.36, 49.47, 50.3 , 50.54, 50.25, 50.99,
#        51.14, 51.69, 52.25, 53.06, 53.38, 53.12, 53.19, 52.62, 52.46,
#        50.49, 50.26, 49.64, 48.9 , 49.22, 49.22, 48.96, 49.31, 48.83,
#        47.65, 47.79, 45.55, 46.23, 46.46, 45.84, 47.28, 47.81, 47.83,
#        48.86])

# %%
oil_series = pd.Series(oil_array, name="oil_price")
oil_series.name, oil_series.dtype, oil_series.size, oil_series.index
# Out:
# ('oil_price', dtype('float64'), 100, RangeIndex(start=0, stop=100, step=1))

# %%
oil_series.mean()
# Out:
# np.float64(51.128299999999996)

# %%
oil_series_int = oil_series.astype(int)
oil_series_int.mean()
# Out:
# np.float64(50.66)

# %% [markdown]
# # Assignment 2:  Accessing Series Data
#
# * Set the date series, which has been created below, to be the index of the oil price series created in assignment 1.
#
#
# * Then, take the mean of the first 10 and last 10 prices of the series.
#
#
# * Finally, grab all oil prices from January 1st, 2017 - January 7th, 2017 (inclusive) and set the index to the default integer index.

# %%
# extract date column from oil DataFrame and grab first 100 rows

dates = pd.Series(oil["date"]).iloc[1000:1100]

# %%
oil_series.index = pd.to_datetime(dates.values)
oil_series
# Out:
# 2016-12-20    52.22
# 2016-12-21    51.44
# 2016-12-22    51.98
# 2016-12-23    52.01
# 2016-12-27    52.82
#               ...
# 2017-05-09    45.84
# 2017-05-10    47.28
# 2017-05-11    47.81
# 2017-05-12    47.83
# 2017-05-15    48.86
# Name: oil_price, Length: 100, dtype: float64

# %%
oil_series.head(10).mean(), oil_series.tail(10).mean()
# Out:
# (np.float64(52.765), np.float64(47.13))

# %%
week = oil_series.loc["2017-01-01":"2017-01-07"].copy()
week.index = range(len(week))
week
# Out:
# 0    52.36
# 1    53.26
# 2    53.77
# 3    53.98
# Name: oil_price, dtype: float64

# %% [markdown]
# # Assignment 3: Sorting and Filtering Series
#
# * First, get the 10 lowest prices from the data.
# * Sort the 10 lowest prices by date, starting with the most recent and ending with the oldest price.
#
# * Finally, use the list of provided dates. Select only rows with these dates that had a price of less than 50 dollars per barrel.

# %%
# list of dates to be used to solve bullet 3

dates = [
    "2016-12-22",
    "2017-05-03",
    "2017-01-06",
    "2017-03-05",
    "2017-02-12",
    "2017-03-21",
    "2017-04-14",
    "2017-04-15",
]

# %%
lowest_10 = oil_series.nsmallest(10)
lowest_10
# Out:
# 2017-05-04    45.55
# 2017-05-09    45.84
# 2017-05-05    46.23
# 2017-05-08    46.46
# 2017-03-23    47.00
# 2017-03-21    47.02
# 2017-03-27    47.02
# 2017-03-14    47.24
# 2017-05-10    47.28
# 2017-03-22    47.29
# Name: oil_price, dtype: float64

# %%
lowest_10.sort_index(ascending=False)
# Out:
# 2017-05-10    47.28
# 2017-05-09    45.84
# 2017-05-08    46.46
# 2017-05-05    46.23
# 2017-05-04    45.55
# 2017-03-27    47.02
# 2017-03-23    47.00
# 2017-03-22    47.29
# 2017-03-21    47.02
# 2017-03-14    47.24
# Name: oil_price, dtype: float64

# %%
picked = oil_series.reindex(pd.to_datetime(dates))
picked[picked < 50]
# Out:
# 2017-05-03    47.79
# 2017-03-21    47.02
# Name: oil_price, dtype: float64

# %% [markdown]
# # Assignment 4: Series Operations
#
# * Increase the prices in the oil series by 10%, and add an additional 2 dollars per barrel on top of that.
#
# * Then, create a series that represents the difference between each price and max price.
#
# * Finally, extract the month from the string dates in the index and store them as an integer in their own series.

# %%
oil_plus = oil_series * 1.10 + 2
oil_plus
# Out:
# 2016-12-20    59.442
# 2016-12-21    58.584
# 2016-12-22    59.178
# 2016-12-23    59.211
# 2016-12-27    60.102
#                ...
# 2017-05-09    52.424
# 2017-05-10    54.008
# 2017-05-11    54.591
# 2017-05-12    54.613
# 2017-05-15    55.746
# Name: oil_price, Length: 100, dtype: float64

# %%
diff_from_max = oil_series.max() - oil_series
diff_from_max
# Out:
# 2016-12-20    2.26
# 2016-12-21    3.04
# 2016-12-22    2.50
# 2016-12-23    2.47
# 2016-12-27    1.66
#               ...
# 2017-05-09    8.64
# 2017-05-10    7.20
# 2017-05-11    6.67
# 2017-05-12    6.65
# 2017-05-15    5.62
# Name: oil_price, Length: 100, dtype: float64

# %%
month_series = pd.Series(oil_series.index.month, index=oil_series.index, name="month")
month_series
# Out:
# 2016-12-20    12
# 2016-12-21    12
# 2016-12-22    12
# 2016-12-23    12
# 2016-12-27    12
#               ..
# 2017-05-09     5
# 2017-05-10     5
# 2017-05-11     5
# 2017-05-12     5
# 2017-05-15     5
# Name: month, Length: 100, dtype: int32

# %% [markdown]
# # Assignment 5: Series Aggregations
#
# * Calculate the sum and mean of prices in the month of March.
#
# * Next, calculate how many prices were recorded in January and February.
#
# * Then, calculate the 10th and 90th percentiles across all data.
#
# * Finally, how often did integer dollar value (e.g. 51, 52) occur in the data? Normalize this to a percentage.

# %%
march = oil_series[oil_series.index.month == 3]
march.sum(), march.mean()
# Out:
# (np.float64(1134.5399999999997), np.float64(49.32782608695651))

# %%
counts = oil_series.groupby(oil_series.index.month).size()
counts.loc[[1, 2]]
# Out:
# 1    20
# 2    19
# Name: oil_price, dtype: int64

# %%
oil_series.quantile([0.1, 0.9])
# Out:
# 0.1    47.299
# 0.9    53.811
# Name: oil_price, dtype: float64

# %%
oil_series.astype(int).value_counts(normalize=True) * 100
# Out:
# oil_price
# 53    26.0
# 52    22.0
# 47    13.0
# 48    10.0
# 51     7.0
# 50     7.0
# 49     6.0
# 54     5.0
# 45     2.0
# 46     2.0
# Name: proportion, dtype: float64

# %% [markdown]
# # Assignment 6: Missing Data
#
# There were some erroneous prices in our data, so they were filled in with missing values.
#
# Can you confirm the number of missing values in the price column?
#
# Once you’ve done that, fill the prices in with the median of the oil price series.

# %%
# Fill in two values with missing data

oil_series = oil_series.where(~oil_series.isin([51.44, 47.83]), pd.NA)

# %%
oil_series.isna().sum()
# Out:
# np.int64(2)

# %%
oil_series = oil_series.fillna(oil_series.median())
oil_series.isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Exercise 7: Apply and Where
#
# Write a function that outputs ‘buy’ if price is less than the 90th percentile and ‘wait’ if it’s not. Apply it to the oil series.
#
# Then, create a series that multiplies price by .9 if the date is ‘2016-12-23’ or ‘2017-05-10’, and 1.1 for all other dates.

# %%
p90 = oil_series.quantile(0.9)

def buy_or_wait(price):
    return "buy" if price < p90 else "wait"

decision_series = oil_series.apply(buy_or_wait)
decision_series
# Out:
# 2016-12-20    buy
# 2016-12-21    buy
# 2016-12-22    buy
# 2016-12-23    buy
# 2016-12-27    buy
#              ...
# 2017-05-09    buy
# 2017-05-10    buy
# 2017-05-11    buy
# 2017-05-12    buy
# 2017-05-15    buy
# Name: oil_price, Length: 100, dtype: str

# %%
special_dates = pd.to_datetime(["2016-12-23", "2017-05-10"])

adjusted_prices = oil_series.where(
    ~oil_series.index.isin(special_dates),
    oil_series * 0.9
)

adjusted_prices = adjusted_prices.where(
    oil_series.index.isin(special_dates),
    oil_series * 1.1
)

adjusted_prices
# Out:
# 2016-12-20    57.4420
# 2016-12-21    57.4255
# 2016-12-22    57.1780
# 2016-12-23    46.8090
# 2016-12-27    58.1020
#                ...
# 2017-05-09    50.4240
# 2017-05-10    42.5520
# 2017-05-11    52.5910
# 2017-05-12    57.4255
# 2017-05-15    53.7460
# Name: oil_price, Length: 100, dtype: float64
